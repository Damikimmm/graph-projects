# %%
from marker import convert

res = convert("test.pdf")

markdown = res.markdown
chunks = res.chunks

print(markdown[:500])
print(chunks[:3])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from marker import convert
#       3 res = convert("test.pdf")
#       5 markdown = res.markdown
#
# ImportError: cannot import name 'convert' from 'marker' (unknown location)

# %%
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']
